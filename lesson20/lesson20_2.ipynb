# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({'key1':['a', 'a', 'b', 'b', 'a'],
                  'key2':['one', 'two', 'one', 'two', 'one'],
                  'data1': np.random.randn(5),
                  'data2':np.random.randn(5)})
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.055103  0.551775
# 1    a  two  0.116447  0.087759
# 2    b  one  0.956645 -0.650643
# 3    b  two  0.257216 -0.419914
# 4    a  one  2.184540  0.743929

# %%
df.groupby(by='key1')[['data1','data2']].sum()
# Out:
#          data1     data2
# key1
# a     2.356089  1.383463
# b     1.213861 -1.070557

# %%
df1 = df.groupby(by=['key1', 'key2']).sum()
df1.columns.name = 'data'
df1
# Out:
# data          data1     data2
# key1 key2
# a    one   2.239642  1.295704
#      two   0.116447  0.087759
# b    one   0.956645 -0.650643
#      two   0.257216 -0.419914

# %%
df1.stack().unstack(level=['key2', 'data'])
# Out:
# key2       one                 two
# data     data1     data2     data1     data2
# key1
# a     2.239642  1.295704  0.116447  0.087759
# b     0.956645 -0.650643  0.257216 -0.419914

# %%
df1 = df.groupby(by=['key1','key2']).agg([('加總', 'sum'),('平均', 'mean')])
df1
# Out:
#               data1               data2
#                  加總        平均        加總        平均
# key1 key2
# a    one   2.239642  1.119821  1.295704  0.647852
#      two   0.116447  0.116447  0.087759  0.087759
# b    one   0.956645  0.956645 -0.650643 -0.650643
#      two   0.257216  0.257216 -0.419914 -0.419914
