# %% [markdown]
# https://www.perplexity.ai/search/00e886a4-379f-4394-ba54-88dc43881fa0

# %%
from matplotlib.font_manager import fontManager
import matplotlib as mpl

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font',family='ChineseFont')

# %%
import numpy as np
import pandas as pd

scores = np.random.randint(50, 101, size=(50,5))

# %%
df = pd.DataFrame(scores,
                columns = ["國文", "英文", "地理", "歷史", "氣候"],
                index = [f"stu{i}" for i in range(1, 51)]
                )

df
# Out:
#        國文  英文   地理  歷史   氣候
# stu1   84  93   59  77   53
# stu2   57  98   73  86   92
# stu3   86  83   64  85   62
# stu4   93  93   56  74   55
# stu5   52  57   82  79   99
# stu6   86  82   84  86   82
# stu7   96  60   68  79   97
# stu8   53  59   97  72   86
# stu9   80  55   64  61   97
# stu10  95  69   92  50   55
# stu11  50  91   88  72   99
# stu12  79  51   73  81   64
# stu13  65  90  100  86   93
# stu14  95  98   68  86   74
# stu15  82  72   80  70   58
# stu16  85  64   62  75   94
# stu17  50  67   69  52  100
# stu18  80  89   78  77   93
# stu19  56  57   75  92   95
# stu20  81  89   51  98   88
# stu21  67  50   60  67   87
# stu22  89  74   93  90   92
# stu23  53  57   55  56   71
# stu24  94  99  100  59   57
# stu25  62  97   71  98   74
# stu26  93  86   70  76   89
# stu27  69  89   53  51   86
# stu28  74  66   74  75   95
# stu29  86  72   93  80   94
# stu30  53  64   63  98   91
# stu31  58  57   75  87   58
# stu32  66  99   77  84   61
# stu33  64  78   53  71   94
# stu34  61  53   57  51   55
# stu35  99  92   65  68   87
# stu36  73  94   72  61   82
# stu37  73  73   89  79   53
# stu38  90  52   66  85   84
# stu39  96  75   74  99   74
# stu40  57  99   89  50   84
# stu41  74  85   61  59   79
# stu42  98  65   62  74   98
# stu43  76  61   83  72   67
# stu44  74  66   72  70   97
# stu45  85  57   82  88   69
# stu46  66  55   68  78   59
# stu47  71  58  100  57   52
# stu48  93  67   78  80   93
# stu49  97  63   87  66   84
# stu50  74  74   73  62   60

# %%
import matplotlib.pyplot as plt

df = pd.DataFrame(scores,
             columns = ["國文","英文","地理","人文","氣候"],
             index=[f"stu{i}" for i in range(1,51)]
             )
name1 = df.loc['stu1'].name
name2 = df.loc['stu2'].name       
figure = plt.figure(figsize=(8, 5),dpi=150,facecolor='#eeeeee')
axes = figure.add_subplot(1,1,1)
axes.plot(df.columns,df.loc['stu1'],marker='o',label=name1)
axes.plot(df.columns,df.loc['stu2'],marker='o',linestyle='-.',label=name2)
axes.set_title(f"{name1} vs {name2}")
axes.set_xlabel("科目")
axes.set_ylabel("分數")
axes.legend()
xlocations = axes.get_xticks()
for index in range(len(xlocations)):
    x = xlocations[index]
    student1_y = df.loc['stu1'].iloc[index]
    student2_y = df.loc['stu2'].iloc[index]
    # print("x座標:",x)
    # print("s1_y_座標:",student1_y)
    # print("s2_y_座標:",student2_y)
    # print("==================")
    axes.annotate(str(student1_y),(x-0.05,student1_y+1))
    if student2_y == 98:
        axes.annotate(str(student2_y),(x,student2_y),xytext=(x+0.3, student2_y+5), arrowprops=dict(facecolor='red', shrink=0.05))
    else:
        axes.annotate(str(student2_y),(x-0.05,student2_y+1))
    axes.set_xlim(-0.5,4.5)
    axes.set_ylim(50,105)
axes.grid(axis='y',color='blue',alpha=0.1,linestyle=':')
plt.show()
