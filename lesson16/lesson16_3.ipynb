# %% [markdown]
# https://www.perplexity.ai/search/8906abee-eea5-4924-8e07-f2f2029af740

# %%
import numpy as np
import pandas as pd

#建立50位學生5個分數,每個分數的值是50~100之間的隨機整數
scores = np.random.randint(50,101, size=(50,5))
score_pd = pd.DataFrame(scores,
            columns=['國文', '英文', '數學', '地理', '歷史'],
            index=[f'學生{index}' for index in range(1,51)])
type(score_pd.index)
score_pd.columns.name = '科目'
score_pd.index.name = '學號'
sum_series = np.sum(score_pd, axis=1)
mean_series = score_pd.mean (axis=1)
score_pd['總分'] = sum_series
score_pd['平均'] = mean_series
score_pd.to_excel('3年7班.xlsx', index=True)

# %%
import os

def rank(filepath:str):
    print (filepath)
    
script_path = os.path.realpath(__name__)
script_root = os.path.dirname(script_path)
excel_folder = os.path.join(script_root,"excel")
for excel_name in os.listdir(excel_folder):
    excel_path = os.path.join (excel_folder, excel_name)
    rank (excel_path)
# Out:
# C:\Users\USER\Documents\Github\python\lesson16\excel\3年5班.xlsx
# C:\Users\USER\Documents\Github\python\lesson16\excel\3年6班.xlsx
# C:\Users\USER\Documents\Github\python\lesson16\excel\3年7班.xlsx

# %%
import os

def rank(filepath:str):
    df = pd.read_excel(filepath, index_col='學號')
    display (df)
    
script_path = os.path.realpath(__name__)
script_root = os.path.dirname(script_path)
excel_folder = os.path.join(script_root,"excel")
for excel_name in os.listdir(excel_folder):
    excel_path = os.path.join (excel_folder, excel_name)
    rank (excel_path)
# Out:
#        國文   英文   數學  地理   歷史   總分    平均
# 學號
# 學生1    79   55   91  68   84  377  75.4
# 學生2    68   90   76  85   91  410  82.0
# 學生3    73   64   59  85   52  333  66.6
# 學生4    66   79   63  98   69  375  75.0
# 學生5    79   85   87  97  100  448  89.6
# 學生6    78   92   53  78   74  375  75.0
# 學生7    64   99   51  50   94  358  71.6
# 學生8    98   88   64  58   53  361  72.2
# 學生9    91   59   93  75   55  373  74.6
# 學生10   87   69  100  64   51  371  74.2
# 學生11   65   91   75  83   53  367  73.4
# 學生12   57   80   70  77   64  348  69.6
# 學生13   79   50   99  95   81  404  80.8
# 學生14   58   96   77  82   89  402  80.4
# 學生15   87   70   94  55   79  385  77.0
# 學生16   77   59   69  62   55  322  64.4
# 學生17  100   85   79  65   62  391  78.2
# 學生18   61   65   88  88   59  361  72.2
# 學生19   87   97   51  87   81  403  80.6
# 學生20   85   90   56  74   85  390  78.0
# 學生21   93   56   52  83   75  359  71.8
# 學生22   68  100   55  71   61  355  71.0
# 學生23   76   83   56  85   62  362  72.4
# 學生24   55   98   61  65   63  342  68.4
# 學生25   76   95   61  63   61  356  71.2
# 學生26   55   87   95  54   76  367  73.4
# 學生27   64   59   94  82   54  353  70.6
# 學生28   82   55   51  71   86  345  69.0
