# %% [markdown]
# https://www.perplexity.ai/search/541099c9-ea3f-4aaa-98b2-53af4156f3cc
#
# 需要安裝jinja2套件

# %%
#Styler.format()
#Styler.fomat_index()
#Styler.relabel_index()

import pandas as pd
import numpy as  np

df = pd.DataFrame ({
    "strings": ["Adams","Mike"],
    "ints": [1,3],
    "floats": [1.123, 1000.23]
})

type(df.style)

display (df)
s = df.style\
.format(precision=3, thousands=",", decimal='.')\
.format_index(str.upper, axis=1)\
.relabel_index(["列1", "列2"])

s
# Out:
#   strings  ints    floats
# 0   Adams     1     1.123
# 1    Mike     3  1000.230
# <style type="text/css">
# </style>
# <table id="T_c6397">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6397_level0_col0" class="col_heading level0 col0" >STRINGS</th>
#       <th id="T_c6397_level0_col1" class="col_heading level0 col1" >INTS</th>
#       <th id="T_c6397_level0_col2" class="col_heading level0 col2" >FLOATS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6397_level0_row0" class="row_heading level0 row0" >列1</th>
#       <td id="T_c6397_row0_col0" class="data row0 col0" >Adams</td>
#       <td id="T_c6397_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_c6397_row0_col2" class="data row0 col2" >1.123</td>
#     </tr>
#     <tr>
#       <th id="T_c6397_level0_row1" class="row_heading level0 row1" >列2</th>
#       <td id="T_c6397_row1_col0" class="data row1 col0" >Mike</td>
#       <td id="T_c6397_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_c6397_row1_col2" class="data row1 col2" >1,000.230</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_df = pd.DataFrame(np.random.rand(600,2)*5,
                    index=pd.date_range(start="2024-01-01", periods=600),
                    columns=['東京', '台北']
                    )

weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 600 entries, 2024-01-01 to 2025-08-22
# Freq: D
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   東京      600 non-null    float64
#  1   台北      600 non-null    float64
# dtypes: float64(2)
# memory usage: 14.1 KB

# %%
#因為索引是datetime的資料
weather_df.loc['2024-01-10':'2024-01-30']
# Out:
#                   東京        台北
# 2024-01-10  3.540501  4.534194
# 2024-01-11  2.291697  0.690857
# 2024-01-12  1.304273  4.439565
# 2024-01-13  3.238382  2.730889
# 2024-01-14  1.258983  0.866305
# 2024-01-15  2.510367  0.519598
# 2024-01-16  1.762051  4.278659
# 2024-01-17  1.970338  1.050843
# 2024-01-18  0.878712  1.451547
# 2024-01-19  3.731929  4.966456
# 2024-01-20  3.356451  4.600243
# 2024-01-21  1.054885  0.075571
# 2024-01-22  0.897312  3.269257
# 2024-01-23  0.235639  3.893551
# 2024-01-24  1.748775  1.433712
# 2024-01-25  2.171592  4.271638
# 2024-01-26  1.390200  0.903521
# 2024-01-27  0.536732  3.917690
# 2024-01-28  4.051933  2.818035
# 2024-01-29  0.955054  1.748834
# 2024-01-30  0.927793  2.716976

# %%
weather_df.loc['2024-01']
# Out:
#                   東京        台北
# 2024-01-01  1.262452  1.191872
# 2024-01-02  3.287591  4.510628
# 2024-01-03  3.918836  1.721770
# 2024-01-04  4.928986  1.902026
# 2024-01-05  4.094951  2.135333
# 2024-01-06  1.815119  1.526877
# 2024-01-07  0.394815  2.805454
# 2024-01-08  1.127671  3.872108
# 2024-01-09  4.845972  3.061436
# 2024-01-10  3.540501  4.534194
# 2024-01-11  2.291697  0.690857
# 2024-01-12  1.304273  4.439565
# 2024-01-13  3.238382  2.730889
# 2024-01-14  1.258983  0.866305
# 2024-01-15  2.510367  0.519598
# 2024-01-16  1.762051  4.278659
# 2024-01-17  1.970338  1.050843
# 2024-01-18  0.878712  1.451547
# 2024-01-19  3.731929  4.966456
# 2024-01-20  3.356451  4.600243
# 2024-01-21  1.054885  0.075571
# 2024-01-22  0.897312  3.269257
# 2024-01-23  0.235639  3.893551
# 2024-01-24  1.748775  1.433712
# 2024-01-25  2.171592  4.271638
# 2024-01-26  1.390200  0.903521
# 2024-01-27  0.536732  3.917690
# 2024-01-28  4.051933  2.818035
# 2024-01-29  0.955054  1.748834
# 2024-01-30  0.927793  2.716976
# 2024-01-31  2.090022  1.998702

# %%
weather_df.loc['2024']
# Out:
#                   東京        台北
# 2024-01-01  1.262452  1.191872
# 2024-01-02  3.287591  4.510628
# 2024-01-03  3.918836  1.721770
# 2024-01-04  4.928986  1.902026
# 2024-01-05  4.094951  2.135333
# ...              ...       ...
# 2024-12-27  1.061136  1.472586
# 2024-12-28  1.106076  1.252082
# 2024-12-29  0.376427  4.833476
# 2024-12-30  2.233339  2.436038
# 2024-12-31  1.468506  0.916022
#
# [366 rows x 2 columns]

# %%
#因為索引是datetime的資料
#weather_df.loc['2024-01-10':'2024-01-30']
#weather_df.loc['2024-01']
#weather_df.loc['2024']

# %%
weather_df = pd.DataFrame(np.random.rand(50,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=50),
                          columns=["Tokyo","Taipei"]
                          )
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 50 entries, 2024-01-01 to 2024-02-19
# Freq: D
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tokyo   50 non-null     float64
#  1   Taipei  50 non-null     float64
# dtypes: float64(2)
# memory usage: 1.2 KB

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(10,6))
axes = figure.add_subplot(1,1,1)
axes.plot(weather_df.index,weather_df['Tokyo'],label='Tokyo',linestyle='',marker='.')
axes.plot(weather_df.index,weather_df['Taipei'],label='Taiepi',linestyle='',marker='.')
plt.show()
plt.close()

# %%
figure = plt.figure(figsize=(10,6))
axes = figure.add_subplot(1,1,1)
weather_df.plot(ax=axes,linestyle='',marker='.')
plt.show()
plt.close()

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                        index=pd.date_range(start="2024-01-01", periods=10),
                        columns=["Tokyo","Taipei"]
                        )

def rain_condition(v):
    if v <1.75:
        return "乾燥"
    elif v <2.75:
        return "小雨"
    else:
        return "大雨"

def make_pretty(styler):
    styler.set_caption("天氣狀況")
    styler.format(rain_condition)
    return styler

s = weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
s
# Out:
# <style type="text/css">
# </style>
# <table id="T_9d5c5">
#   <caption>天氣狀況</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d5c5_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_9d5c5_level0_col1" class="col_heading level0 col1" >Taipei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d5c5_level0_row0" class="row_heading level0 row0" >2024-01-01 00:00:00</th>
#       <td id="T_9d5c5_row0_col0" class="data row0 col0" >大雨</td>
#       <td id="T_9d5c5_row0_col1" class="data row0 col1" >大雨</td>
#     </tr>
#     <tr>
#       <th id="T_9d5c5_level0_row1" class="row_heading level0 row1" >2024-01-02 00:00:00</th>
#       <td id="T_9d5c5_row1_col0" class="data row1 col0" >乾燥</td>
#       <td id="T_9d5c5_row1_col1" class="data row1 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_9d5c5_level0_row2" class="row_heading level0 row2" >2024-01-03 00:00:00</th>
#       <td id="T_9d5c5_row2_col0" class="data row2 col0" >小雨</td>
#       <td id="T_9d5c5_row2_col1" class="data row2 col1" >大雨</td>
#     </tr>
#     <tr>
#       <th id="T_9d5c5_level0_row3" class="row_heading level0 row3" >2024-01-04 00:00:00</th>
#       <td id="T_9d5c5_row3_col0" class="data row3 col0" >大雨</td>
#       <td id="T_9d5c5_row3_col1" class="data row3 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_9d5c5_level0_row4" class="row_heading level0 row4" >2024-01-05 00:00:00</th>
#       <td id="T_9d5c5_row4_col0" class="data row4 col0" >小雨</td>
#       <td id="T_9d5c5_row4_col1" class="data row4 col1" >乾燥</td>
#     </tr>
#     <tr>
#       <th id="T_9d5c5_level0_row5" class="row_heading level0 row5" >2024-01-06 00:00:00</th>
#       <td id="T_9d5c5_row5_col0" class="data row5 col0" >大雨</td>
#       <td id="T_9d5c5_row5_col1" class="data row5 col1" >大雨</td>
#     </tr>
#     <tr>
#       <th id="T_9d5c5_level0_row6" class="row_heading level0 row6" >2024-01-07 00:00:00</th>
#       <td id="T_9d5c5_row6_col0" class="data row6 col0" >大雨</td>
#       <td id="T_9d5c5_row6_col1" class="data row6 col1" >乾燥</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                        index=pd.date_range(start="2024-01-01", periods=10),
                        columns=["Tokyo","Taipei"]
                        )
display (weather_df)

def rain_condition(v):
    if v <1.75:
        return "乾燥"
    elif v <2.75:
        return "小雨"
    else:
        return "大雨"

def make_pretty(styler):
    styler.set_caption("天氣狀況")
    styler.format(rain_condition)
    styler.format_index(formatter=lambda v:v.strftime("%Y/%m/%d %A"))
    styler.background_gradient(axis=None, vmin=1, vmax=5, cmap='PuBuGn')
    return styler

s = weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
s
# Out:
#                Tokyo    Taipei
# 2024-01-01  1.824430  3.076981
# 2024-01-02  0.376906  1.844120
# 2024-01-03  4.665701  3.256891
# 2024-01-04  1.986013  3.943651
# 2024-01-05  1.584181  2.840493
# 2024-01-06  4.345637  2.180867
# 2024-01-07  4.010738  0.718834
# 2024-01-08  3.521305  3.522907
# 2024-01-09  1.093961  4.624338
# 2024-01-10  2.210704  4.546580
# <style type="text/css">
# #T_7c088_row0_col0 {
#   background-color: #dad7ea;
#   color: #000000;
# }
# #T_7c088_row0_col1 {
#   background-color: #60a5cd;
#   color: #f1f1f1;
# }
# #T_7c088_row1_col0, #T_7c088_row6_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_7c088_row1_col1 {
#   background-color: #d9d6e9;
#   color: #000000;
# }
# #T_7c088_row2_col0 {
#   background-color: #015f4d;
#   color: #f1f1f1;
# }
# #T_7c088_row2_col1 {
#   background-color: #4e9cc7;
#   color: #f1f1f1;
# }
# #T_7c088_row3_col0 {
#   background-color: #d1d1e6;
#   color: #000000;
# }
# #T_7c088_row3_col1 {
#   background-color: #078390;
#   color: #f1f1f1;
# }
# #T_7c088_row4_col0 {
#   background-color: #e7dfee;
#   color: #000000;
# }
# #T_7c088_row4_col1 {
#   background-color: #7cb0d3;
#   color: #f1f1f1;
# }
# #T_7c088_row5_col0 {
#   background-color: #017267;
#   color: #f1f1f1;
# }
# #T_7c088_row5_col1 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_7c088_row6_col0 {
#   background-color: #028189;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7c088">
#   <caption>天氣狀況</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c088_level0_col0" class="col_heading level0 col0" >Tokyo</th>
#       <th id="T_7c088_level0_col1" class="col_heading level0 col1" >Taipei</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c088_level0_row0" class="row_heading level0 row0" >2024/01/01 Monday</th>
#       <td id="T_7c088_row0_col0" class="data row0 col0" >小雨</td>
#       <td id="T_7c088_row0_col1" class="data row0 col1" >大雨</td>
#     </tr>
#     <tr>
#       <th id="T_7c088_level0_row1" class="row_heading level0 row1" >2024/01/02 Tuesday</th>
#       <td id="T_7c088_row1_col0" class="data row1 col0" >乾燥</td>
#       <td id="T_7c088_row1_col1" class="data row1 col1" >小雨</td>
#     </tr>
#     <tr>
#       <th id="T_7c088_level0_row2" class="row_heading level0 row2" >2024/01/03 Wednesday</th>
#       <td id="T_7c088_row2_col0" class="data row2 col0" >大雨</td>
#       <td id="T_7c088_row2_col1" class="data row2 col1" >大雨</td>
#     </tr>
#     <tr>
#       <th id="T_7c088_level0_row3" class="row_heading level0 row3" >2024/01/04 Thursday</th>
#       <td id="T_7c088_row3_col0" class="data row3 col0" >小雨</td>
#       <td id="T_7c088_row3_col1" class="data row3 col1" >大雨</td>
#     </tr>
#     <tr>
#       <th id="T_7c088_level0_row4" class="row_heading level0 row4" >2024/01/05 Friday</th>
#       <td id="T_7c088_row4_col0" class="data row4 col0" >乾燥</td>
#       <td id="T_7c088_row4_col1" class="data row4 col1" >大雨</td>
#     </tr>
#     <tr>
#       <th id="T_7c088_level0_row5" class="row_heading level0 row5" >2024/01/06 Saturday</th>
#       <td id="T_7c088_row5_col0" class="data row5 col0" >大雨</td>
#       <td id="T_7c088_row5_col1" class="data row5 col1" >小雨</td>
#     </tr>
#     <tr>
#       <th id="T_7c088_level0_row6" class="row_heading level0 row6" >2024/01/07 Sunday</th>
#       <td id="T_7c088_row6_col0" class="data row6 col0" >大雨</td>
#       <td id="T_7c088_row6_col1" class="data row6 col1" >乾燥</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.random.seed(1234) ##須設定,否則每次執行亂數產生的結果會不一
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                        index=pd.date_range(start="2024-01-01", periods=10),
                        columns=["Tokyo","Taipei"]
                        )
display (weather_df)

def rain_condition(v):
    if v <1.75:
        return "乾燥"
    elif v <2.75:
        return "小雨"
    else:
        return "大雨"

def make_pretty(styler):
    styler.set_caption("天氣狀況")
    styler.format(rain_condition)
    styler.format_index(formatter=lambda v:v.strftime("%Y/%m/%d %A"))
    styler.background_gradient(axis=None, vmin=1, vmax=5, cmap='PuBuGn')
    return styler

s = weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
s
s.to_excel('weather_condition.xlsx')
# Out:
#                Tokyo    Taipei
# 2024-01-01  0.957597  3.110544
# 2024-01-02  2.188639  3.926793
# 2024-01-03  3.899879  1.362963
# 2024-01-04  1.382321  4.009361
# 2024-01-05  4.790697  4.379663
# 2024-01-06  1.789086  2.504976
# 2024-01-07  3.417315  3.563510
# 2024-01-08  1.851254  2.805981
# 2024-01-09  2.515416  0.068842
# 2024-01-10  3.864133  4.413206
